# %%
import os
import sklearn
import requests
import json
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.preprocessing import StandardScaler
import itertools

# %%
# Get the data
with open("home_data.json", "r") as data:
    home_data = json.load(data) 
# Sample user preferences
user_preferences= {
            "state": "District of Columbia",
            "baths":2,
            "beds":2,
            "cats":True,
            "dogs":True,
            "price_range":"$1135 - $2831",
            "sqft_range":"500+",
            "type":"Apartment",
            "city": "Washington",
            "postal_code": "20002"
        }
# Sample user liked houses
user_liked_houses = ['6786270504', '6541999527']

# %%
# Get the data needed
data_needed = {}
for i in range(0,100):
    details = []
    if home_data["data"]["results"][i]["details"] != None:
        details = home_data["data"]["results"][i]["details"][0]["text"]
    if (home_data["data"]["results"][i]["list_price_min"] != None) and (home_data["data"]["results"][i]["list_price_max"] != None):
        price_range = []
        price_range.append(home_data["data"]["results"][i]["list_price_min"])
        price_range.append(home_data["data"]["results"][i]["list_price_max"])
    else: 
        price_range = home_data["data"]["results"][i]["list_price"]
    if (home_data["data"]["results"][i]["description"]["sqft_min"] != None) and (home_data["data"]["results"][i]["description"]["sqft_max"] != None):
        sqft_range = []
        sqft_range.append(home_data["data"]["results"][i]["description"]["sqft_min"])
        sqft_range.append(home_data["data"]["results"][i]["description"]["sqft_max"])
    else:
        sqft_range = home_data["data"]["results"][i]["description"]["sqft"]
    # get the data needed from the API
    data_needed[f"{i}"] = {
        "property_id": home_data["data"]["results"][i]["property_id"],
        "list_price_min": home_data["data"]["results"][i]["list_price_min"],
        "list_price_max": home_data["data"]["results"][i]["list_price_max"],
        "baths": home_data["data"]["results"][i]["description"]["baths_max"],
        "beds": home_data["data"]["results"][i]["description"]["beds_max"],
        "sqft_max": home_data["data"]["results"][i]["description"]["sqft_max"],
        "type": home_data["data"]["results"][i]["description"]["type"],
        "street_name": home_data["data"]["results"][i]["location"]["address"]["street_name"],
        "city": home_data["data"]["results"][i]["location"]["address"]["city"],
        "postal_code": home_data["data"]["results"][i]["location"]["address"]["postal_code"],
        "state": home_data["data"]["results"][i]["location"]["address"]["state"],
        "cats": home_data["data"]["results"][i]["pet_policy"]["cats"],
        "dogs": home_data["data"]["results"][i]["pet_policy"]["dogs"],
        # NOTE: THE COMMENTED INFO WILL BE NEEDED FOR ACCUARCY LATER ON
        # "list_price": home_data["data"]["results"][i]["list_price"],
        # "sqft": home_data["data"]["results"][i]["description"]["sqft"],
        # "line": home_data["data"]["results"][i]["location"]["address"]["line"],
        # "price_range": price_range,
        # "sqft_range": sqft_range,
        # "other_details": details,
        # "postal_code": home_data["data"]["results"][i]["location"]["address"]["neighborhoods"],
    }
with open("ml_data.json", "w") as outfile:
    json.dump(data_needed, outfile, indent=3)

# %%
# Convert the data price ranges and sqft to int
def process_ranges(df):
    df['list_price_min'] = df['price_range'].str.split('-').str[0].str.replace('$', '').astype(int)
    df['list_price_max'] = df['price_range'].str.split('-').str[1].str.replace('$', '').astype(int)
    df['sqft'] = df['sqft_range'].str.split('+').str[0].astype(int)
    df = df.drop(['price_range', 'sqft_range'], axis=1)
    return df

# Data Preparation
# Create DataFrames from the given data
house_data = pd.DataFrame.from_dict(data_needed).T
user_preferences = pd.DataFrame.from_dict([user_preferences])
user_liked_houses = pd.DataFrame({'property_id': user_liked_houses})
house_data = house_data.dropna()

# Feature Engineering
user_preferences = process_ranges(user_preferences)

# Normalize house data numerical features
scaler = MinMaxScaler()
house_data[['list_price_min', 'list_price_max','sqft_max']] = scaler.fit_transform(house_data[['list_price_min', 'list_price_max','sqft_max']])

# Encode house data categorical features using label encoding
categorical_features = ['state', 'baths', 'beds', 'cats', 'dogs', 'type', 'city', 'state', 'postal_code', 'street_name']
encoder = LabelEncoder()
for cols in categorical_features:
    label = encoder.fit_transform(house_data[cols])
    house_data[cols] = label

# Fill null values in the data with zero
house_data = house_data.fillna(0)

# %%
# NOTE: A MORE THOROUGH FILTERING WILL BE USED FOR THIS PART LATER ON. BUT HERE IS A BASIC IMPLEMENTATION THAT WORKS
# Filter houses based on user preferences: Creates a new dataframe containing only houses that matches the user
# Matches all preferences
all_filtered_houses = house_data[
    (house_data['state'] == user_preferences['state'].values[0]) &
    (house_data['baths'] == user_preferences['baths'].values[0]) &
    (house_data['beds'] == user_preferences['beds'].values[0]) &
    (house_data['cats'] == user_preferences['cats'].values[0]) &
    (house_data['dogs'] == user_preferences['dogs'].values[0]) &
    (house_data['list_price_min'] >= user_preferences['list_price_min'].values[0]) &
    (house_data['list_price_max'] <= user_preferences['list_price_max'].values[0]) &
    (house_data['sqft_max'] >= user_preferences['sqft'].values[0]) &
    (house_data['type'] == user_preferences['type'].values[0]) &
    (house_data['city'] == user_preferences['city'].values[0]) &
    (house_data['postal_code'] == user_preferences['postal_code'].values[0])
]
# Matches some preferences
some_filtered_houses = house_data[
    (house_data['state'] == user_preferences['state'].values[0]) |
    (house_data['baths'] == user_preferences['baths'].values[0]) |
    (house_data['beds'] == user_preferences['beds'].values[0]) |
    (house_data['cats'] == user_preferences['cats'].values[0]) |
    (house_data['dogs'] == user_preferences['dogs'].values[0]) |
    (house_data['list_price_min'] >= user_preferences['list_price_min'].values[0]) &
    (house_data['list_price_max'] <= user_preferences['list_price_max'].values[0]) &
    (house_data['sqft_max'] >= user_preferences['sqft'].values[0]) |
    (house_data['type'] == user_preferences['type'].values[0]) |
    (house_data['city'] == user_preferences['city'].values[0]) |
    (house_data['postal_code'] == user_preferences['postal_code'].values[0])
]
filtered_houses = pd.concat([all_filtered_houses,some_filtered_houses], axis=0)
filtered_houses.drop_duplicates(inplace=True)
# print(filtered_houses)

# %%
# Content based recommendation
def content_based():
    # Select relevant features for similarity calculation
    features = ['state','city','postal_code','baths', 'cats','dogs','beds', 'list_price_min', 'list_price_max', 'sqft_max','type','list_price_min','list_price_max','sqft_max']
    
    # Create a feature matrix for filtered houses
    feature_matrix = filtered_houses[features]
    
    # Calculate cosine similarity
    similarity_scores = cosine_similarity(feature_matrix)

    # Get indices of liked houses
    liked_house_indices = filtered_houses.index[filtered_houses['property_id'].isin(user_liked_houses['property_id'])].to_list()
    
    #Convert the indices to int
    liked_house_indices = list(map(int,liked_house_indices))

    # Recommend houses based on similarity to liked houses
    recommended_indices = similarity_scores[liked_house_indices].argsort()[:, ::-1]
    recommended_houses = filtered_houses.iloc[recommended_indices[:, 1:].ravel()]  # Exclude already liked houses
    recommended_houses.drop_duplicates(inplace=True)

    # Convert all the indices results from every liked houses into one list
    all_recommended_indices = list(itertools.chain.from_iterable(recommended_indices))
    # delete duplicates indices in the newly created list
    all_recommended_indices = list(set(all_recommended_indices))

    # Calculate similarity score
    scores = similarity_scores[0][all_recommended_indices]

    # sort or rank the houses
    ranked_houses = list(zip(all_recommended_indices,scores)) #save the indices and scores as a tuple
    ranked_houses.sort(key=lambda x: x[1], reverse=True) #rank the results

    # Print the ranked recommendation along with the house details
    for house_id, score in ranked_houses:
        # Get the house details using the house ID        house_id = str(house_id)
        try:
            house_details = recommended_houses.loc[house_id]
            # Print the house details and score
            print(f"Recommended House ID: {house_id}")
            print(f"Score: {score}")
            print(f"House Details:")
            print(house_details)
            print("\n")
        except:
            print(f"House id {house_id} returns an error")
content_based()
# 7,12,85,53,18,71,52,8,65,17,12,43
# TODO: IMPLEMENT TEST CASES AND EVALAUTE AND CALCULATE THE ACCURACY OF THE MODEL
# Out:
# Recommended House ID: 0
# Score: 1.0000000000000002
# House Details:
# property_id       5379274332
# list_price_min      0.004965
# list_price_max      0.161578
# baths                      2
# beds                       2
# sqft_max               0.604
# type                       0
# street_name               56
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 0, dtype: object
#
#
# Recommended House ID: 40
# Score: 0.9969641374518707
# House Details:
# property_id       5041621842
# list_price_min      0.236677
# list_price_max      0.247664
# baths                      2
# beds                       2
# sqft_max            0.533143
# type                       0
# street_name               63
# city                       0
# postal_code                2
# state                      0
# cats                       1
# dogs                       1
# Name: 40, dtype: object
#
#
# Recommended House ID: 21
# Score: 0.9953072347832096
# House Details:
# property_id       6908347987
# list_price_min      0.166832
# list_price_max      0.084528
# baths                      2
# beds                       2
# sqft_max            0.414286
# type                       0
# street_name               33
# city                       0
# postal_code                0
# state                      0
# cats                       1
# dogs                       1
# Name: 21, dtype: object
#
#
# Recommended House ID: 77
# Score: 0.9935988018310964
# House Details:
# property_id       5851952645
# list_price_min      0.268123
# list_price_max      0.068017
# baths                      0
# beds                       1
# sqft_max            0.219429
# type                       0
# street_name               48
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       0
# Name: 77, dtype: object
#
#
# Recommended House ID: 58
# Score: 0.9777478401727876
# House Details:
# property_id       5639224855
# list_price_min       0.11718
# list_price_max      0.144133
# baths                      2
# beds                       2
# sqft_max            0.490857
# type                       0
# street_name                8
# city                       0
# postal_code                9
# state                      0
# cats                       0
# dogs                       0
# Name: 58, dtype: object
#
#
# Recommended House ID: 42
# Score: 0.9657240482686922
# House Details:
# property_id       5464074926
# list_price_min      0.165508
# list_price_max      0.035826
# baths                      0
# beds                       0
# sqft_max            0.133714
# type                       0
# street_name                3
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       0
# Name: 42, dtype: object
#
#
# Recommended House ID: 13
# Score: 0.9656435047916356
# House Details:
# property_id       5458410502
# list_price_min      0.114532
# list_price_max      0.077051
# baths                      0
# beds                       1
# sqft_max               0.344
# type                       0
# street_name               57
# city                       0
# postal_code                9
# state                      0
# cats                       1
# dogs                       1
# Name: 13, dtype: object
#
#
# Recommended House ID: 26
# Score: 0.9637458390835693
# House Details:
# property_id       9966966857
# list_price_min      0.216816
# list_price_max      0.132399
# baths                      2
# beds                       2
# sqft_max            0.506857
# type                       0
# street_name               14
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 26, dtype: object
#
#
# Recommended House ID: 35
# Score: 0.9636538232968727
# House Details:
# property_id       9482239406
# list_price_min      0.357498
# list_price_max      0.277778
# baths                      2
# beds                       2
# sqft_max                 1.0
# type                       0
# street_name               13
# city                       0
# postal_code                3
# state                      0
# cats                       0
# dogs                       0
# Name: 35, dtype: object
#
#
# Recommended House ID: 2
# Score: 0.9535897004950874
# House Details:
# property_id       6541999527
# list_price_min      0.142337
# list_price_max      0.286397
# baths                      2
# beds                       2
# sqft_max            0.593714
# type                       0
# street_name               12
# city                       0
# postal_code                0
# state                      0
# cats                       1
# dogs                       1
# Name: 2, dtype: object
#
#
# Recommended House ID: 78
# Score: 0.9524378791194557
# House Details:
# property_id       5459118555
# list_price_min      0.158888
# list_price_max      0.038941
# baths                      0
# beds                       0
# sqft_max            0.177714
# type                       0
# street_name               21
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       0
# Name: 78, dtype: object
#
#
# Recommended House ID: 87
# Score: 0.9506277133705408
# House Details:
# property_id       5428485950
# list_price_min      0.173784
# list_price_max      0.095535
# baths                      0
# beds                       1
# sqft_max            0.425714
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 87, dtype: object
#
#
# Recommended House ID: 16
# Score: 0.9506150736865082
# House Details:
# property_id       5647721490
# list_price_min      0.190334
# list_price_max      0.234995
# baths                      2
# beds                       2
# sqft_max            0.565714
# type                       0
# street_name                5
# city                       0
# postal_code                2
# state                      0
# cats                       1
# dogs                       1
# Name: 16, dtype: object
#
#
# Recommended House ID: 83
# Score: 0.9504801862451322
# House Details:
# property_id       5682595871
# list_price_min      0.223105
# list_price_max      0.246106
# baths                      2
# beds                       2
# sqft_max            0.610857
# type                       0
# street_name               11
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 83, dtype: object
#
#
# House id 43 returns an error
# Recommended House ID: 69
# Score: 0.9023416872839923
# House Details:
# property_id       5067782748
# list_price_min      0.176432
# list_price_max      0.093873
# baths                      1
# beds                       2
# sqft_max            0.480571
# type                       0
# street_name               62
# city                       0
# postal_code               12
# state                      0
# cats                       1
# dogs                       1
# Name: 69, dtype: object
#
#
# House id 12 returns an error
# Recommended House ID: 49
# Score: 0.8655611439773351
# House Details:
# property_id       6274747906
# list_price_min      0.245945
# list_price_max      0.553998
# baths                      3
# beds                       2
# sqft_max               0.804
# type                       0
# street_name               53
# city                       0
# postal_code                0
# state                      0
# cats                       1
# dogs                       1
# Name: 49, dtype: object
#
#
# Recommended House ID: 30
# Score: 0.8134521036089368
# House Details:
# property_id       6287977316
# list_price_min      0.572658
# list_price_max      0.163551
# baths                      0
# beds                       1
# sqft_max            0.335429
# type                       0
# street_name               23
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 30, dtype: object
#
#
# Recommended House ID: 84
# Score: 0.7989016134840873
# House Details:
# property_id       9277568359
# list_price_min      0.200265
# list_price_max      0.209242
# baths                      2
# beds                       2
# sqft_max            0.462857
# type                       0
# street_name               24
# city                       0
# postal_code               10
# state                      0
# cats                       0
# dogs                       1
# Name: 84, dtype: object
#
#
# Recommended House ID: 62
# Score: 0.7591002548254137
# House Details:
# property_id       5441119105
# list_price_min           1.0
# list_price_max      0.322845
# baths                      2
# beds                       2
# sqft_max            0.630857
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 62, dtype: object
#
#
# Recommended House ID: 41
# Score: 0.7523341159822873
# House Details:
# property_id       5577023351
# list_price_min           0.0
# list_price_max      0.018172
# baths                      0
# beds                       1
# sqft_max            0.254857
# type                       0
# street_name               28
# city                       0
# postal_code               17
# state                      0
# cats                       1
# dogs                       0
# Name: 41, dtype: object
#
#
# Recommended House ID: 75
# Score: 0.7200063740073074
# House Details:
# property_id       5455615557
# list_price_min      0.854022
# list_price_max      0.251817
# baths                      2
# beds                       2
# sqft_max            0.483429
# type                       0
# street_name               38
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       1
# Name: 75, dtype: object
#
#
# Recommended House ID: 66
# Score: 0.7179500686859441
# House Details:
# property_id       6457372760
# list_price_min       0.22145
# list_price_max      0.207477
# baths                      0
# beds                       2
# sqft_max               0.552
# type                       0
# street_name                9
# city                       0
# postal_code                5
# state                      0
# cats                       1
# dogs                       1
# Name: 66, dtype: object
#
#
# Recommended House ID: 25
# Score: 0.716580766774934
# House Details:
# property_id       6733385576
# list_price_min      0.222112
# list_price_max      0.251506
# baths                      2
# beds                       2
# sqft_max            0.586286
# type                       0
# street_name               42
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 25, dtype: object
#
#
# Recommended House ID: 6
# Score: 0.7126998357240568
# House Details:
# property_id       5525238059
# list_price_min       0.13671
# list_price_max      0.179024
# baths                      2
# beds                       2
# sqft_max               0.544
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 6, dtype: object
#
#
# Recommended House ID: 29
# Score: 0.7119542148186708
# House Details:
# property_id       5721275506
# list_price_min      0.304866
# list_price_max      0.309346
# baths                      0
# beds                       2
# sqft_max            0.547429
# type                       0
# street_name               56
# city                       0
# postal_code                5
# state                      0
# cats                       1
# dogs                       1
# Name: 29, dtype: object
#
#
# Recommended House ID: 63
# Score: 0.705724932954436
# House Details:
# property_id       5565951024
# list_price_min      0.206885
# list_price_max       0.14839
# baths                      2
# beds                       2
# sqft_max            0.506857
# type                       0
# street_name               31
# city                       0
# postal_code                9
# state                      0
# cats                       0
# dogs                       1
# Name: 63, dtype: object
#
#
# Recommended House ID: 54
# Score: 0.7023489315882189
# House Details:
# property_id       6771407354
# list_price_min      0.400199
# list_price_max      0.189823
# baths                      0
# beds                       2
# sqft_max            0.369143
# type                       0
# street_name               43
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 54, dtype: object
#
#
# Recommended House ID: 5
# Score: 0.6856242796493656
# House Details:
# property_id       6661127647
# list_price_min      0.239987
# list_price_max      0.069574
# baths                      0
# beds                       1
# sqft_max            0.262857
# type                       0
# street_name               54
# city                       0
# postal_code                2
# state                      0
# cats                       1
# dogs                       1
# Name: 5, dtype: object
#
#
# Recommended House ID: 32
# Score: 0.680052159812723
# House Details:
# property_id       6463335616
# list_price_min      0.182059
# list_price_max      0.155244
# baths                      2
# beds                       2
# sqft_max            0.537714
# type                       0
# street_name                8
# city                       0
# postal_code                9
# state                      0
# cats                       1
# dogs                       1
# Name: 32, dtype: object
#
#
# House id 17 returns an error
# Recommended House ID: 82
# Score: 0.6665684630856379
# House Details:
# property_id       5445330156
# list_price_min      0.241642
# list_price_max      0.234268
# baths                      0
# beds                       2
# sqft_max            0.496571
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 82, dtype: object
#
#
# House id 65 returns an error
# Recommended House ID: 33
# Score: 0.652797306053531
# House Details:
# property_id       9415167781
# list_price_min      0.200596
# list_price_max      0.326584
# baths                      2
# beds                       2
# sqft_max            0.489714
# type                       0
# street_name               41
# city                       0
# postal_code               10
# state                      0
# cats                       1
# dogs                       1
# Name: 33, dtype: object
#
#
# House id 8 returns an error
# Recommended House ID: 57
# Score: 0.60638031111859
# House Details:
# property_id       5568754958
# list_price_min      0.284674
# list_price_max      0.498442
# baths                      2
# beds                       3
# sqft_max            0.630286
# type                       0
# street_name               45
# city                       0
# postal_code                4
# state                      0
# cats                       1
# dogs                       1
# Name: 57, dtype: object
#
#
# Recommended House ID: 24
# Score: 0.6060963937637244
# House Details:
# property_id       9091701101
# list_price_min      0.207878
# list_price_max      0.351713
# baths                      2
# beds                       2
# sqft_max            0.594286
# type                       0
# street_name                0
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 24, dtype: object
#
#
# Recommended House ID: 27
# Score: 0.599411300766329
# House Details:
# property_id       9200901531
# list_price_min      0.154585
# list_price_max      0.137175
# baths                      2
# beds                       2
# sqft_max               0.604
# type                       0
# street_name               39
# city                       0
# postal_code               14
# state                      0
# cats                       1
# dogs                       1
# Name: 27, dtype: object
#
#
# Recommended House ID: 28
# Score: 0.5729624406455504
# House Details:
# property_id       5465000768
# list_price_min      0.275405
# list_price_max      0.134891
# baths                      0
# beds                       2
# sqft_max            0.382286
# type                       0
# street_name                4
# city                       0
# postal_code                8
# state                      0
# cats                       1
# dogs                       1
# Name: 28, dtype: object
#
#
# Recommended House ID: 55
# Score: 0.5710697389233201
# House Details:
# property_id       5018850639
# list_price_min      0.224429
# list_price_max      0.243821
# baths                      2
# beds                       2
# sqft_max            0.612571
# type                       0
# street_name               46
# city                       0
# postal_code               12
# state                      0
# cats                       0
# dogs                       0
# Name: 55, dtype: object
#
#
# Recommended House ID: 14
# Score: 0.5704072529623762
# House Details:
# property_id       9342233213
# list_price_min       0.10096
# list_price_max      0.015576
# baths                      0
# beds                       1
# sqft_max            0.296571
# type                       0
# street_name               19
# city                       0
# postal_code                9
# state                      0
# cats                       1
# dogs                       0
# Name: 14, dtype: object
#
#
# Recommended House ID: 72
# Score: 0.5651031560625938
# House Details:
# property_id       5498396859
# list_price_min       0.18901
# list_price_max        0.1054
# baths                      0
# beds                       1
# sqft_max            0.275429
# type                       0
# street_name               59
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 72, dtype: object
#
#
# House id 52 returns an error
# Recommended House ID: 61
# Score: 0.5536492382523185
# House Details:
# property_id       5441976222
# list_price_min      0.114201
# list_price_max      0.143614
# baths                      0
# beds                       1
# sqft_max            0.296571
# type                       0
# street_name                4
# city                       0
# postal_code                8
# state                      0
# cats                       1
# dogs                       1
# Name: 61, dtype: object
#
#
# Recommended House ID: 74
# Score: 0.546244318431933
# House Details:
# property_id       5435939139
# list_price_min      0.175439
# list_price_max       0.04351
# baths                      0
# beds                       0
# sqft_max            0.210857
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       0
# Name: 74, dtype: object
#
#
# Recommended House ID: 50
# Score: 0.5430917071386734
# House Details:
# property_id       9412152919
# list_price_min       0.17577
# list_price_max      0.039045
# baths                      0
# beds                       1
# sqft_max               0.268
# type                       0
# street_name               29
# city                       0
# postal_code                9
# state                      0
# cats                       1
# dogs                       0
# Name: 50, dtype: object
#
#
# Recommended House ID: 59
# Score: 0.5396090751559679
# House Details:
# property_id       5152321841
# list_price_min      0.284343
# list_price_max      0.079335
# baths                      0
# beds                       0
# sqft_max            0.234286
# type                       0
# street_name               27
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       1
# Name: 59, dtype: object
#
#
# House id 71 returns an error
# House id 18 returns an error
# Recommended House ID: 56
# Score: 0.5160229877293909
# House Details:
# property_id       6783363760
# list_price_min      0.319431
# list_price_max      0.084112
# baths                      0
# beds                       2
# sqft_max            0.439429
# type                       0
# street_name               12
# city                       0
# postal_code               12
# state                      0
# cats                       1
# dogs                       1
# Name: 56, dtype: object
#
#
# Recommended House ID: 45
# Score: 0.5138204917918435
# House Details:
# property_id       9971250618
# list_price_min       0.41708
# list_price_max      0.314849
# baths                      2
# beds                       2
# sqft_max            0.328571
# type                       0
# street_name                7
# city                       0
# postal_code               19
# state                      0
# cats                       1
# dogs                       1
# Name: 45, dtype: object
#
#
# Recommended House ID: 38
# Score: 0.5113520910016024
# House Details:
# property_id       5349258557
# list_price_min      0.166832
# list_price_max      0.262201
# baths                      0
# beds                       2
# sqft_max            0.478286
# type                       0
# street_name               45
# city                       0
# postal_code                4
# state                      0
# cats                       1
# dogs                       1
# Name: 38, dtype: object
#
#
# Recommended House ID: 23
# Score: 0.5034654266477446
# House Details:
# property_id       9158955054
# list_price_min      0.559748
# list_price_max      0.205088
# baths                      3
# beds                       3
# sqft_max            0.613714
# type                       0
# street_name               17
# city                       0
# postal_code               17
# state                      0
# cats                       1
# dogs                       1
# Name: 23, dtype: object
#
#
# Recommended House ID: 22
# Score: 0.5019074969158286
# House Details:
# property_id       9020517687
# list_price_min      0.566369
# list_price_max           1.0
# baths                      4
# beds                       3
# sqft_max            0.909714
# type                       0
# street_name               61
# city                       0
# postal_code               11
# state                      0
# cats                       1
# dogs                       1
# Name: 22, dtype: object
#
#
# Recommended House ID: 34
# Score: 0.5007343997457924
# House Details:
# property_id       5638149710
# list_price_min      0.125455
# list_price_max       0.23053
# baths                      2
# beds                       2
# sqft_max            0.510857
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 34, dtype: object
#
#
# Recommended House ID: 47
# Score: 0.4904455895318949
# House Details:
# property_id       9173104214
# list_price_min      0.252565
# list_price_max      0.063136
# baths                      0
# beds                       1
# sqft_max            0.259429
# type                       0
# street_name               27
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 47, dtype: object
#
#
# Recommended House ID: 76
# Score: 0.4892614662502238
# House Details:
# property_id       6746799973
# list_price_min      0.215161
# list_price_max      0.298546
# baths                      2
# beds                       3
# sqft_max            0.652571
# type                       0
# street_name               21
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       1
# Name: 76, dtype: object
#
#
# Recommended House ID: 60
# Score: 0.48781973604220463
# House Details:
# property_id       6705708997
# list_price_min      0.337306
# list_price_max       0.14891
# baths                      0
# beds                       1
# sqft_max            0.308571
# type                       0
# street_name                3
# city                       0
# postal_code                4
# state                      0
# cats                       1
# dogs                       1
# Name: 60, dtype: object
#
#
# Recommended House ID: 70
# Score: 0.4869222272753234
# House Details:
# property_id       9750192392
# list_price_min      0.081761
# list_price_max       0.26999
# baths                      2
# beds                       2
# sqft_max            0.610857
# type                       0
# street_name               44
# city                       0
# postal_code               11
# state                      0
# cats                       1
# dogs                       1
# Name: 70, dtype: object
#
#
# Recommended House ID: 1
# Score: 0.47890459671930274
# House Details:
# property_id       6786270504
# list_price_min      0.208871
# list_price_max      0.340602
# baths                      2
# beds                       2
# sqft_max            0.623429
# type                       0
# street_name               43
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 1, dtype: object
#
#
# Recommended House ID: 3
# Score: 0.478491241487965
# House Details:
# property_id       5508300611
# list_price_min      0.213505
# list_price_max      0.253167
# baths                      2
# beds                       2
# sqft_max            0.623429
# type                       0
# street_name                5
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 3, dtype: object
#
#
# Recommended House ID: 19
# Score: 0.47839139270368547
# House Details:
# property_id       5670416449
# list_price_min      0.279709
# list_price_max      0.122638
# baths                      2
# beds                       2
# sqft_max            0.453714
# type                       0
# street_name               15
# city                       0
# postal_code               10
# state                      0
# cats                       1
# dogs                       1
# Name: 19, dtype: object
#
#
# Recommended House ID: 73
# Score: 0.4782080917997525
# House Details:
# property_id       5886117291
# list_price_min      0.239325
# list_price_max      0.219938
# baths                      2
# beds                       2
# sqft_max            0.365143
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 73, dtype: object
#
#
# Recommended House ID: 20
# Score: 0.4777584061698312
# House Details:
# property_id       5466161818
# list_price_min      0.091029
# list_price_max      0.074766
# baths                      0
# beds                       1
# sqft_max            0.260571
# type                       0
# street_name               26
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       0
# Name: 20, dtype: object
#
#
# Recommended House ID: 86
# Score: 0.45840635042859884
# House Details:
# property_id       5441156371
# list_price_min      0.103277
# list_price_max      0.223572
# baths                      2
# beds                       2
# sqft_max            0.762286
# type                       0
# street_name               64
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 86, dtype: object
#
#
# Recommended House ID: 39
# Score: 0.4457825971503701
# House Details:
# property_id       9734095827
# list_price_min      0.152267
# list_price_max      0.187435
# baths                      2
# beds                       2
# sqft_max            0.536571
# type                       0
# street_name               39
# city                       0
# postal_code               14
# state                      0
# cats                       1
# dogs                       1
# Name: 39, dtype: object
#
#
# Recommended House ID: 80
# Score: 0.4442441837454795
# House Details:
# property_id       6734077919
# list_price_min      0.167163
# list_price_max      0.067497
# baths                      0
# beds                       1
# sqft_max            0.382286
# type                       0
# street_name               22
# city                       0
# postal_code                6
# state                      0
# cats                       1
# dogs                       1
# Name: 80, dtype: object
#
#
# House id 53 returns an error
# Recommended House ID: 48
# Score: 0.44063521553576884
# House Details:
# property_id       9905446954
# list_price_min      0.233035
# list_price_max      0.244341
# baths                      2
# beds                       2
# sqft_max            0.710286
# type                       0
# street_name               36
# city                       0
# postal_code                2
# state                      0
# cats                       1
# dogs                       1
# Name: 48, dtype: object
#
#
# Recommended House ID: 10
# Score: 0.42657381337840483
# House Details:
# property_id       5765558818
# list_price_min      0.043032
# list_price_max       0.08567
# baths                      0
# beds                       2
# sqft_max            0.296571
# type                       0
# street_name               16
# city                       0
# postal_code                2
# state                      0
# cats                       0
# dogs                       0
# Name: 10, dtype: object
#
#
# Recommended House ID: 15
# Score: 0.4211392345168127
# House Details:
# property_id       9458554997
# list_price_min      0.482622
# list_price_max      0.153998
# baths                      1
# beds                       2
# sqft_max            0.553714
# type                       0
# street_name               54
# city                       0
# postal_code                2
# state                      0
# cats                       1
# dogs                       1
# Name: 15, dtype: object
#
#
# Recommended House ID: 67
# Score: 0.41874683271753044
# House Details:
# property_id       9356931592
# list_price_min      0.179411
# list_price_max      0.274766
# baths                      2
# beds                       3
# sqft_max            0.582857
# type                       0
# street_name               59
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 67, dtype: object
#
#
# House id 85 returns an error
# Recommended House ID: 79
# Score: 0.4054329906553214
# House Details:
# property_id       5353357810
# list_price_min      0.241642
# list_price_max      0.178609
# baths                      2
# beds                       2
# sqft_max            0.408571
# type                       0
# street_name               42
# city                       0
# postal_code                0
# state                      0
# cats                       1
# dogs                       0
# Name: 79, dtype: object
#
#
# Recommended House ID: 46
# Score: 0.40466049748910904
# House Details:
# property_id       9015515475
# list_price_min      0.167163
# list_price_max      0.259605
# baths                      2
# beds                       2
# sqft_max               0.592
# type                       0
# street_name               34
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 46, dtype: object
#
#
# Recommended House ID: 11
# Score: 0.394919409271251
# House Details:
# property_id       5550941838
# list_price_min      0.011586
# list_price_max      0.049844
# baths                      0
# beds                       2
# sqft_max            0.425143
# type                       0
# street_name               58
# city                       0
# postal_code               15
# state                      0
# cats                       0
# dogs                       0
# Name: 11, dtype: object
#
#
# Recommended House ID: 44
# Score: 0.39405525159169974
# House Details:
# property_id       9391702773
# list_price_min      0.209533
# list_price_max      0.456386
# baths                      2
# beds                       3
# sqft_max            0.679429
# type                       0
# street_name               35
# city                       0
# postal_code               16
# state                      0
# cats                       1
# dogs                       1
# Name: 44, dtype: object
#
#
# Recommended House ID: 51
# Score: 0.3788085800062505
# House Details:
# property_id       9734641962
# list_price_min      0.168487
# list_price_max      0.136137
# baths                      2
# beds                       2
# sqft_max            0.486857
# type                       0
# street_name               37
# city                       0
# postal_code               13
# state                      0
# cats                       1
# dogs                       1
# Name: 51, dtype: object
#
#
# Recommended House ID: 9
# Score: 0.3756858817707827
# House Details:
# property_id       5545575542
# list_price_min      0.047997
# list_price_max      0.010384
# baths                      0
# beds                       1
# sqft_max            0.296571
# type                       0
# street_name               54
# city                       0
# postal_code               15
# state                      0
# cats                       1
# dogs                       0
# Name: 9, dtype: object
#
#
# Recommended House ID: 81
# Score: 0.35826894222082756
# House Details:
# property_id       5448758623
# list_price_min      0.209533
# list_price_max      0.189512
# baths                      0
# beds                       2
# sqft_max            0.413143
# type                       0
# street_name               30
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       1
# Name: 81, dtype: object
#
#
# Recommended House ID: 31
# Score: 0.35517672287103413
# House Details:
# property_id       5823822267
# list_price_min      0.360808
# list_price_max      0.259917
# baths                      4
# beds                       3
# sqft_max            0.689143
# type                       0
# street_name               49
# city                       0
# postal_code                1
# state                      0
# cats                       1
# dogs                       1
# Name: 31, dtype: object
#
#
# House id 7 returns an error
# Recommended House ID: 64
# Score: 0.34749889098912257
# House Details:
# property_id       9009389984
# list_price_min      0.192982
# list_price_max      0.200519
# baths                      2
# beds                       2
# sqft_max            0.565714
# type                       0
# street_name               18
# city                       0
# postal_code               13
# state                      0
# cats                       1
# dogs                       1
# Name: 64, dtype: object
#
#
# Recommended House ID: 36
# Score: 0.34684735428776226
# House Details:
# property_id       5572966010
# list_price_min      0.079775
# list_price_max       0.02108
# baths                      0
# beds                       1
# sqft_max            0.305143
# type                       0
# street_name               54
# city                       0
# postal_code               15
# state                      0
# cats                       1
# dogs                       0
# Name: 36, dtype: object
#
#
# Recommended House ID: 68
# Score: 0.33864125955935725
# House Details:
# property_id       9245649252
# list_price_min      0.390599
# list_price_max      0.106438
# baths                      2
# beds                       2
# sqft_max            0.414857
# type                       0
# street_name               48
# city                       0
# postal_code                9
# state                      0
# cats                       0
# dogs                       0
# Name: 68, dtype: object
#
#
# Recommended House ID: 37
# Score: 0.33649433040286963
# House Details:
# property_id       9437861642
# list_price_min      0.383648
# list_price_max      0.358775
# baths                      2
# beds                       4
# sqft_max            0.590857
# type                       0
# street_name               20
# city                       0
# postal_code                9
# state                      0
# cats                       1
# dogs                       1
# Name: 37, dtype: object
#
#
# Recommended House ID: 4
# Score: 0.33443637817645017
# House Details:
# property_id       5332041691
# list_price_min      0.157233
# list_price_max      0.033229
# baths                      0
# beds                       0
# sqft_max            0.091429
# type                       0
# street_name                6
# city                       0
# postal_code                7
# state                      0
# cats                       1
# dogs                       0
# Name: 4, dtype: object
